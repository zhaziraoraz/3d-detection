# %%
import cv2
import mediapipe as mp
import time

# %%
mp_facedetector = mp.solutions.face_detection
mp_draw = mp.solutions.drawing_utils

cap = cv2.VideoCapture(0)


with mp_facedetector.FaceDetection(min_detection_confidence=0.7) as face_detection:

    while cap.isOpened():

        success, image = cap.read()

        start = time.time()


        # Convert the BGR image to RGB
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # Process the image and find faces
        results = face_detection.process(image)
        
        # Convert the image color back so it can be displayed
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)


        if results.detections:
            for id, detection in enumerate(results.detections):
                mp_draw.draw_detection(image, detection)
                print(id, detection)

                bBox = detection.location_data.relative_bounding_box

                h, w, c = image.shape

                boundBox = int(bBox.xmin * w), int(bBox.ymin * h), int(bBox.width * w), int(bBox.height * h)

                cv2.putText(image, f'{int(detection.score[0]*100)}%', (boundBox[0], boundBox[1] - 20), cv2.FONT_HERSHEY_SIMPLEX, 2, (0,255,0), 2)





        end = time.time()
        totalTime = end - start

        fps = 1 / totalTime
        print("FPS: ", fps)

        cv2.putText(image, f'FPS: {int(fps)}', (20,70), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0,255,0), 2)

        cv2.imshow('Face Detection', image)

        if cv2.waitKey(5) & 0xFF == 27:
            break

cap.release()
# Out:
# 0 label_id: 0
# score: 0.8430385589599609
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6566572189331055
#     ymin: 0.4379063844680786
#     width: 0.3840538263320923
#     height: 0.6826471090316772
#   }
#   relative_keypoints {
#     x: 0.7652398943901062
#     y: 0.6389448046684265
#   }
#   relative_keypoints {
#     x: 0.9259966611862183
#     y: 0.6031272411346436
#   }
#   relative_keypoints {
#     x: 0.8589325547218323
#     y: 0.7846669554710388
#   }
#   relative_keypoints {
#     x: 0.8684651851654053
#     y: 0.9318856596946716
#   }
#   relative_keypoints {
#     x: 0.6814126968383789
#     y: 0.718797504901886
#   }
#   relative_keypoints {
#     x: 1.0142892599105835
#     y: 0.6411811709403992
#   }
# }
#
# FPS:  52.26026065937352
# 0 label_id: 0
# score: 0.8406829237937927
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6582292318344116
#     ymin: 0.45310676097869873
#     width: 0.37003469467163086
#     height: 0.6577273607254028
#   }
#   relative_keypoints {
#     x: 0.7667836546897888
#     y: 0.6327677369117737
#   }
#   relative_keypoints {
#     x: 0.9203894138336182
#     y: 0.6174471974372864
#   }
#   relative_keypoints {
#     x: 0.8494106531143188
#     y: 0.7775997519493103
#   }
#   relative_keypoints {
#     x: 0.8523946404457092
#     y: 0.9237502217292786
#   }
#   relative_keypoints {
#     x: 0.6831398010253906
#     y: 0.7046899199485779
#   }
#   relative_keypoints {
#     x: 1.003017544746399
#     y: 0.671996533870697
#   }
# }
#
# FPS:  186.59596049470593
# 0 label_id: 0
# score: 0.8150702118873596
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6584916710853577
#     ymin: 0.4576725363731384
#     width: 0.3439564108848572
#     height: 0.6114190220832825
#   }
#   relative_keypoints {
#     x: 0.7589671015739441
#     y: 0.6323179602622986
#   }
#   relative_keypoints {
#     x: 0.9071847796440125
#     y: 0.6242358088493347
#   }
#   relative_keypoints {
#     x: 0.8422496318817139
#     y: 0.7772789597511292
#   }
#   relative_keypoints {
#     x: 0.8448281288146973
#     y: 0.9055997729301453
#   }
#   relative_keypoints {
#     x: 0.6727718114852905
#     y: 0.6871954798698425
#   }
#   relative_keypoints {
#     x: 0.9822055697441101
#     y: 0.6591622233390808
#   }
# }
#
# FPS:  188.643698839615
# 0 label_id: 0
# score: 0.809287965297699
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6566216945648193
#     ymin: 0.44834113121032715
#     width: 0.353413462638855
#     height: 0.6282320022583008
#   }
#   relative_keypoints {
#     x: 0.762457549571991
#     y: 0.6259104609489441
#   }
#   relative_keypoints {
#     x: 0.9152269959449768
#     y: 0.6248127818107605
#   }
#   relative_keypoints {
#     x: 0.8474859595298767
#     y: 0.7807579636573792
#   }
#   relative_keypoints {
#     x: 0.8476096987724304
#     y: 0.9115553498268127
#   }
#   relative_keypoints {
#     x: 0.6703819632530212
#     y: 0.675032913684845
#   }
#   relative_keypoints {
#     x: 0.989202082157135
#     y: 0.6599774956703186
#   }
# }
#
# FPS:  169.92683223271078
# 0 label_id: 0
# score: 0.825752317905426
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6622976064682007
#     ymin: 0.4640185236930847
#     width: 0.3463171720504761
#     height: 0.6156166195869446
#   }
#   relative_keypoints {
#     x: 0.7641445398330688
#     y: 0.6401781439781189
#   }
#   relative_keypoints {
#     x: 0.9133527874946594
#     y: 0.6272818446159363
#   }
#   relative_keypoints {
#     x: 0.8495326042175293
#     y: 0.7822555899620056
#   }
#   relative_keypoints {
#     x: 0.8526193499565125
#     y: 0.9130697846412659
#   }
#   relative_keypoints {
#     x: 0.6762363910675049
#     y: 0.7007740139961243
#   }
#   relative_keypoints {
#     x: 0.9881770014762878
#     y: 0.6630464196205139
#   }
# }
#
# FPS:  156.39883660228205
# 0 label_id: 0
# score: 0.8459458351135254
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6603542566299438
#     ymin: 0.45618873834609985
#     width: 0.3549232482910156
#     height: 0.6309160590171814
#   }
#   relative_keypoints {
#     x: 0.7624110579490662
#     y: 0.6459140181541443
#   }
#   relative_keypoints {
#     x: 0.9158199429512024
#     y: 0.6341695189476013
#   }
#   relative_keypoints {
#     x: 0.8494771122932434
#     y: 0.7996888756752014
#   }
#   relative_keypoints {
#     x: 0.8532217741012573
#     y: 0.9245695471763611
#   }
#   relative_keypoints {
#     x: 0.674140453338623
#     y: 0.693296492099762
#   }
#   relative_keypoints {
#     x: 0.9950282573699951
#     y: 0.6565379500389099
#   }
# }
#
# FPS:  138.7739544732663
# 0 label_id: 0
# score: 0.8591452240943909
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6592340469360352
#     ymin: 0.4660019874572754
#     width: 0.3600348234176636
#     height: 0.6400010585784912
#   }
#   relative_keypoints {
#     x: 0.7622981667518616
#     y: 0.6574508547782898
#   }
#   relative_keypoints {
#     x: 0.9188238382339478
#     y: 0.6345632672309875
#   }
#   relative_keypoints {
#     x: 0.8547995686531067
#     y: 0.802846372127533
#   }
#   relative_keypoints {
#     x: 0.8605654835700989
#     y: 0.9354659914970398
#   }
#   relative_keypoints {
#     x: 0.6718456745147705
#     y: 0.7213861346244812
#   }
#   relative_keypoints {
#     x: 0.9995031952857971
#     y: 0.6627916693687439
#   }
# }
#
# FPS:  135.3394211222613
# 0 label_id: 0
# score: 0.8666425943374634
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6576968431472778
#     ymin: 0.44528400897979736
#     width: 0.37606143951416016
#     height: 0.6684666872024536
#   }
#   relative_keypoints {
#     x: 0.7599562406539917
#     y: 0.6568594574928284
#   }
#   relative_keypoints {
#     x: 0.9211308360099792
#     y: 0.6221838593482971
#   }
#   relative_keypoints {
#     x: 0.8547136187553406
#     y: 0.8098767399787903
#   }
#   relative_keypoints {
#     x: 0.8650122284889221
#     y: 0.941501796245575
#   }
#   relative_keypoints {
#     x: 0.6753181219100952
#     y: 0.7164667248725891
#   }
#   relative_keypoints {
#     x: 1.0110152959823608
#     y: 0.6367865204811096
#   }
# }
#
# FPS:  185.2525948500508
# 0 label_id: 0
# score: 0.873723030090332
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6608883738517761
#     ymin: 0.4707988500595093
#     width: 0.3568567633628845
#     height: 0.6343499422073364
#   }
#   relative_keypoints {
#     x: 0.7610965967178345
#     y: 0.6565977931022644
#   }
#   relative_keypoints {
#     x: 0.9170121550559998
#     y: 0.6317067742347717
#   }
#   relative_keypoints {
#     x: 0.8530810475349426
#     y: 0.797274649143219
#   }
#   relative_keypoints {
#     x: 0.8594871759414673
#     y: 0.9323665499687195
#   }
#   relative_keypoints {
#     x: 0.6727529168128967
#     y: 0.7256289124488831
#   }
#   relative_keypoints {
#     x: 0.9987613558769226
#     y: 0.6635283827781677
#   }
# }
#
# FPS:  182.7503812470045
# 0 label_id: 0
# score: 0.8642991781234741
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6597572565078735
#     ymin: 0.4600405693054199
#     width: 0.3608360290527344
#     height: 0.6414239406585693
#   }
#   relative_keypoints {
#     x: 0.7596505284309387
#     y: 0.6552674174308777
#   }
#   relative_keypoints {
#     x: 0.9169783592224121
#     y: 0.634402334690094
#   }
#   relative_keypoints {
#     x: 0.8502098321914673
#     y: 0.8076545596122742
#   }
#   relative_keypoints {
#     x: 0.8571193814277649
#     y: 0.9359899163246155
#   }
#   relative_keypoints {
#     x: 0.6735449433326721
#     y: 0.7094282507896423
#   }
#   relative_keypoints {
#     x: 1.0011985301971436
#     y: 0.65377277135849
#   }
# }
#
# FPS:  188.89857683300306
# 0 label_id: 0
# score: 0.868091344833374
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6563147306442261
#     ymin: 0.4514382481575012
#     width: 0.37994468212127686
#     height: 0.6753308176994324
#   }
#   relative_keypoints {
#     x: 0.7629428505897522
#     y: 0.6463455557823181
#   }
#   relative_keypoints {
#     x: 0.9231548309326172
#     y: 0.6222887635231018
#   }
#   relative_keypoints {
#     x: 0.8511571884155273
#     y: 0.7967658638954163
#   }
#   relative_keypoints {
#     x: 0.8581835627555847
#     y: 0.9396305680274963
#   }
#   relative_keypoints {
#     x: 0.6790235638618469
#     y: 0.715326726436615
#   }
#   relative_keypoints {
#     x: 1.0132960081100464
#     y: 0.6637575030326843
#   }
# }
#
# FPS:  224.55851804261698
# 0 label_id: 0
# score: 0.8673187494277954
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6534159779548645
#     ymin: 0.451643705368042
#     width: 0.3823382258415222
#     height: 0.6795854568481445
#   }
#   relative_keypoints {
#     x: 0.7638879418373108
#     y: 0.6455371975898743
#   }
#   relative_keypoints {
#     x: 0.9260121583938599
#     y: 0.6212599873542786
#   }
#   relative_keypoints {
#     x: 0.8561553955078125
#     y: 0.7959364056587219
#   }
#   relative_keypoints {
#     x: 0.862128734588623
#     y: 0.9410457015037537
#   }
#   relative_keypoints {
#     x: 0.6747332811355591
#     y: 0.7181558012962341
#   }
#   relative_keypoints {
#     x: 1.0123529434204102
#     y: 0.6653129458427429
#   }
# }
#
# FPS:  180.53217406275556
# 0 label_id: 0
# score: 0.8603242635726929
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6544524431228638
#     ymin: 0.4487431049346924
#     width: 0.38244152069091797
#     height: 0.6797711849212646
#   }
#   relative_keypoints {
#     x: 0.7641163468360901
#     y: 0.6501427292823792
#   }
#   relative_keypoints {
#     x: 0.9245190620422363
#     y: 0.6255831122398376
#   }
#   relative_keypoints {
#     x: 0.854234516620636
#     y: 0.8066206574440002
#   }
#   relative_keypoints {
#     x: 0.8608514070510864
#     y: 0.945912778377533
#   }
#   relative_keypoints {
#     x: 0.6775856614112854
#     y: 0.7141364216804504
#   }
#   relative_keypoints {
#     x: 1.01112961769104
#     y: 0.6607787013053894
#   }
# }
#
# FPS:  220.21967867268717
# 0 label_id: 0
# score: 0.8632212281227112
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6541461944580078
#     ymin: 0.45423394441604614
#     width: 0.3726174831390381
#     height: 0.6623460650444031
#   }
#   relative_keypoints {
#     x: 0.7608779668807983
#     y: 0.6498880982398987
#   }
#   relative_keypoints {
#     x: 0.9216490387916565
#     y: 0.638505756855011
#   }
#   relative_keypoints {
#     x: 0.8500677943229675
#     y: 0.814509928226471
#   }
#   relative_keypoints {
#     x: 0.8535933494567871
#     y: 0.9466918110847473
#   }
#   relative_keypoints {
#     x: 0.6705734729766846
#     y: 0.7001057267189026
#   }
#   relative_keypoints {
#     x: 1.003861427307129
#     y: 0.6670456528663635
#   }
# }
#
# FPS:  219.8272536687631
# 0 label_id: 0
# score: 0.8683061003684998
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6531206965446472
#     ymin: 0.449664831161499
#     width: 0.37458425760269165
#     height: 0.6658422946929932
#   }
#   relative_keypoints {
#     x: 0.7606821656227112
#     y: 0.6493397355079651
#   }
#   relative_keypoints {
#     x: 0.9221699237823486
#     y: 0.6322880387306213
#   }
#   relative_keypoints {
#     x: 0.8536925911903381
#     y: 0.8110684752464294
#   }
#   relative_keypoints {
#     x: 0.85849928855896
#     y: 0.9443507790565491
#   }
#   relative_keypoints {
#     x: 0.6687048077583313
#     y: 0.7031826376914978
#   }
#   relative_keypoints {
#     x: 1.0035734176635742
#     y: 0.6573165059089661
#   }
# }
#
# FPS:  211.85493484190323
# 0 label_id: 0
# score: 0.8658401370048523
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.647876501083374
#     ymin: 0.44653183221817017
#     width: 0.3876684904098511
#     height: 0.6890637278556824
#   }
#   relative_keypoints {
#     x: 0.7580769658088684
#     y: 0.6623044610023499
#   }
#   relative_keypoints {
#     x: 0.9207323789596558
#     y: 0.6317465901374817
#   }
#   relative_keypoints {
#     x: 0.8518425226211548
#     y: 0.8288883566856384
#   }
#   relative_keypoints {
#     x: 0.8603696227073669
#     y: 0.9613205790519714
#   }
#   relative_keypoints {
#     x: 0.6716493368148804
#     y: 0.7172558903694153
#   }
#   relative_keypoints {
#     x: 1.0071943998336792
#     y: 0.6501358151435852
#   }
# }
# FPS:  215.3354553855632
# 0 label_id: 0
# score: 0.8642408847808838
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6493121981620789
#     ymin: 0.4485413432121277
#     width: 0.3863733410835266
#     height: 0.686761200428009
#   }
#   relative_keypoints {
#     x: 0.7637457251548767
#     y: 0.6555796265602112
#   }
#   relative_keypoints {
#     x: 0.9252610802650452
#     y: 0.6311985850334167
#   }
#   relative_keypoints {
#     x: 0.8581986427307129
#     y: 0.818855345249176
#   }
#   relative_keypoints {
#     x: 0.8636710047721863
#     y: 0.9558548331260681
#   }
#   relative_keypoints {
#     x: 0.6722093224525452
#     y: 0.7146255373954773
#   }
#   relative_keypoints {
#     x: 1.0064697265625
#     y: 0.6597893834114075
#   }
# }
#
# FPS:  226.44984342943528
# 0 label_id: 0
# score: 0.8529598116874695
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6560018658638
#     ymin: 0.46371108293533325
#     width: 0.3738568425178528
#     height: 0.6645166277885437
#   }
#   relative_keypoints {
#     x: 0.7654070854187012
#     y: 0.6557822823524475
#   }
#   relative_keypoints {
#     x: 0.9223138689994812
#     y: 0.6338652968406677
#   }
#   relative_keypoints {
#     x: 0.8542929291725159
#     y: 0.8090954422950745
#   }
#   relative_keypoints {
#     x: 0.8593297004699707
#     y: 0.9488173127174377
#   }
#   relative_keypoints {
#     x: 0.6792845726013184
#     y: 0.7229958176612854
#   }
#   relative_keypoints {
#     x: 1.0041149854660034
#     y: 0.6741686463356018
#   }
# }
#
# FPS:  226.5599308593961
# 0 label_id: 0
# score: 0.8518005609512329
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6522372961044312
#     ymin: 0.4389491677284241
#     width: 0.3979611396789551
#     height: 0.7073609232902527
#   }
#   relative_keypoints {
#     x: 0.7671208381652832
#     y: 0.6608508229255676
#   }
#   relative_keypoints {
#     x: 0.934582531452179
#     y: 0.6470585465431213
#   }
#   relative_keypoints {
#     x: 0.8583457469940186
#     y: 0.8441535830497742
#   }
#   relative_keypoints {
#     x: 0.8630939722061157
#     y: 0.9753621220588684
#   }
#   relative_keypoints {
#     x: 0.677049994468689
#     y: 0.6985560059547424
#   }
#   relative_keypoints {
#     x: 1.0225305557250977
#     y: 0.6630619168281555
#   }
# }
#
# FPS:  227.41983408339206
# 0 label_id: 0
# score: 0.8524468541145325
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6562677025794983
#     ymin: 0.4565145969390869
#     width: 0.38856619596481323
#     height: 0.690657377243042
#   }
#   relative_keypoints {
#     x: 0.7642154097557068
#     y: 0.666739284992218
#   }
#   relative_keypoints {
#     x: 0.927609384059906
#     y: 0.6411945223808289
#   }
#   relative_keypoints {
#     x: 0.8530964851379395
#     y: 0.8315250277519226
#   }
#   relative_keypoints {
#     x: 0.861049234867096
#     y: 0.969183623790741
#   }
#   relative_keypoints {
#     x: 0.6815020442008972
#     y: 0.7263793349266052
#   }
#   relative_keypoints {
#     x: 1.0188941955566406
#     y: 0.6711675524711609
#   }
# }
#
# FPS:  226.96450216450216
# 0 label_id: 0
# score: 0.8386185169219971
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6611774563789368
#     ymin: 0.4741990566253662
#     width: 0.3600638508796692
#     height: 0.6400501728057861
#   }
#   relative_keypoints {
#     x: 0.758645236492157
#     y: 0.6695781350135803
#   }
#   relative_keypoints {
#     x: 0.9160009026527405
#     y: 0.6471225619316101
#   }
#   relative_keypoints {
#     x: 0.8466337323188782
#     y: 0.82241290807724
#   }
#   relative_keypoints {
#     x: 0.8545321226119995
#     y: 0.951890766620636
#   }
#   relative_keypoints {
#     x: 0.6765704154968262
#     y: 0.7260017991065979
#   }
#   relative_keypoints {
#     x: 1.0029726028442383
#     y: 0.669046938419342
#   }
# }
#
# FPS:  225.84018953262978
# 0 label_id: 0
# score: 0.805950403213501
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6526809334754944
#     ymin: 0.45678871870040894
#     width: 0.40498846769332886
#     height: 0.7198475003242493
#   }
#   relative_keypoints {
#     x: 0.7589707374572754
#     y: 0.6635206341743469
#   }
#   relative_keypoints {
#     x: 0.9312047958374023
#     y: 0.6454388499259949
#   }
#   relative_keypoints {
#     x: 0.8425983190536499
#     y: 0.8366479277610779
#   }
#   relative_keypoints {
#     x: 0.850724995136261
#     y: 0.9870672821998596
#   }
#   relative_keypoints {
#     x: 0.6825723648071289
#     y: 0.7306683659553528
#   }
#   relative_keypoints {
#     x: 1.0339946746826172
#     y: 0.6955977082252502
#   }
# }
#
# FPS:  214.4107964420816
# 0 label_id: 0
# score: 0.8337318301200867
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6531407833099365
#     ymin: 0.4546161890029907
#     width: 0.3927035331726074
#     height: 0.6980096101760864
#   }
#   relative_keypoints {
#     x: 0.7552794218063354
#     y: 0.6531105637550354
#   }
#   relative_keypoints {
#     x: 0.9210598468780518
#     y: 0.6340048909187317
#   }
#   relative_keypoints {
#     x: 0.8363966345787048
#     y: 0.8163482546806335
#   }
#   relative_keypoints {
#     x: 0.8458539843559265
#     y: 0.9636773467063904
#   }
#   relative_keypoints {
#     x: 0.6826524138450623
#     y: 0.7198838591575623
#   }
#   relative_keypoints {
#     x: 1.024104356765747
#     y: 0.6794231534004211
#   }
# }
#
# FPS:  216.73749483257544
# 0 label_id: 0
# score: 0.8218729496002197
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6511164307594299
#     ymin: 0.46571123600006104
#     width: 0.3784946799278259
#     height: 0.6727536916732788
#   }
#   relative_keypoints {
#     x: 0.7548876404762268
#     y: 0.6619510054588318
#   }
#   relative_keypoints {
#     x: 0.9117891192436218
#     y: 0.6400317549705505
#   }
#   relative_keypoints {
#     x: 0.8361810445785522
#     y: 0.8242762684822083
#   }
#   relative_keypoints {
#     x: 0.8451122641563416
#     y: 0.9622635245323181
#   }
#   relative_keypoints {
#     x: 0.6820201873779297
#     y: 0.7229648232460022
#   }
#   relative_keypoints {
#     x: 1.0046319961547852
#     y: 0.6752058863639832
#   }
# }
#
# FPS:  201.97938938649716
# 0 label_id: 0
# score: 0.849784791469574
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6529936790466309
#     ymin: 0.4580256938934326
#     width: 0.38417840003967285
#     height: 0.6828567981719971
#   }
#   relative_keypoints {
#     x: 0.7527700066566467
#     y: 0.6645331978797913
#   }
#   relative_keypoints {
#     x: 0.9134684205055237
#     y: 0.644589364528656
#   }
#   relative_keypoints {
#     x: 0.8326399326324463
#     y: 0.8327744603157043
#   }
#   relative_keypoints {
#     x: 0.8421415090560913
#     y: 0.9663984179496765
#   }
#   relative_keypoints {
#     x: 0.6814724206924438
#     y: 0.7137593626976013
#   }
#   relative_keypoints {
#     x: 1.013319969177246
#     y: 0.6712291836738586
#   }
# }
#
# FPS:  224.82332761578044
# 0 label_id: 0
# score: 0.8420224189758301
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6565152406692505
#     ymin: 0.45700323581695557
#     width: 0.37932491302490234
#     height: 0.6742357015609741
#   }
#   relative_keypoints {
#     x: 0.7500447630882263
#     y: 0.6740075945854187
#   }
#   relative_keypoints {
#     x: 0.9108806252479553
#     y: 0.641178548336029
#   }
#   relative_keypoints {
#     x: 0.8317137956619263
#     y: 0.8364548087120056
#   }
#   relative_keypoints {
#     x: 0.8467785716056824
#     y: 0.9645779728889465
#   }
#   relative_keypoints {
#     x: 0.6840930581092834
#     y: 0.7252327799797058
#   }
#   relative_keypoints {
#     x: 1.0158921480178833
#     y: 0.6541696190834045
#   }
# }
#
# FPS:  233.75711976815472
# 0 label_id: 0
# score: 0.8586152791976929
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6528915166854858
#     ymin: 0.4530208110809326
#     width: 0.38983988761901855
#     height: 0.6929221153259277
#   }
#   relative_keypoints {
#     x: 0.7503946423530579
#     y: 0.6711106896400452
#   }
#   relative_keypoints {
#     x: 0.9155182242393494
#     y: 0.6349238753318787
#   }
#   relative_keypoints {
#     x: 0.8349997401237488
#     y: 0.8297575116157532
#   }
#   relative_keypoints {
#     x: 0.8490514755249023
#     y: 0.9666168093681335
#   }
#   relative_keypoints {
#     x: 0.679132342338562
#     y: 0.7348485589027405
#   }
#   relative_keypoints {
#     x: 1.021519660949707
#     y: 0.6612337231636047
#   }
# }
#
# FPS:  225.93751346692522
# 0 label_id: 0
# score: 0.8528458476066589
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6533325910568237
#     ymin: 0.4469711184501648
#     width: 0.38881075382232666
#     height: 0.6910944581031799
#   }
#   relative_keypoints {
#     x: 0.7497324347496033
#     y: 0.6772252917289734
#   }
#   relative_keypoints {
#     x: 0.9144324660301208
#     y: 0.6539451479911804
#   }
#   relative_keypoints {
#     x: 0.8300984501838684
#     y: 0.8576866984367371
#   }
#   relative_keypoints {
#     x: 0.8427417278289795
#     y: 0.9781085848808289
#   }
#   relative_keypoints {
#     x: 0.6806713342666626
#     y: 0.7062353491783142
#   }
#   relative_keypoints {
#     x: 1.020992636680603
#     y: 0.6552522778511047
#   }
# }
#
# FPS:  218.78378801314486
# 0 label_id: 0
# score: 0.863419234752655
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6487887501716614
#     ymin: 0.4567883014678955
#     width: 0.38586539030075073
#     height: 0.6858584880828857
#   }
#   relative_keypoints {
#     x: 0.7445458173751831
#     y: 0.676678478717804
#   }
#   relative_keypoints {
#     x: 0.9087623953819275
#     y: 0.6505802273750305
#   }
#   relative_keypoints {
#     x: 0.8264713883399963
#     y: 0.8511655926704407
#   }
#   relative_keypoints {
#     x: 0.8386881351470947
#     y: 0.9767809510231018
#   }
#   relative_keypoints {
#     x: 0.6745144724845886
#     y: 0.7173594832420349
#   }
#   relative_keypoints {
#     x: 1.0120666027069092
#     y: 0.662723958492279
#   }
# }
#
# FPS:  226.14460559659244
# 0 label_id: 0
# score: 0.8804517388343811
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6477945446968079
#     ymin: 0.43733787536621094
#     width: 0.37880605459213257
#     height: 0.6733124256134033
#   }
#   relative_keypoints {
#     x: 0.7462480068206787
#     y: 0.6715090870857239
#   }
#   relative_keypoints {
#     x: 0.9052390456199646
#     y: 0.6525866389274597
#   }
#   relative_keypoints {
#     x: 0.8271080255508423
#     y: 0.8585142493247986
#   }
#   relative_keypoints {
#     x: 0.8364436626434326
#     y: 0.9659481644630432
#   }
#   relative_keypoints {
#     x: 0.6728110313415527
#     y: 0.6836312413215637
#   }
#   relative_keypoints {
#     x: 1.0014331340789795
#     y: 0.6395662426948547
#   }
# }
#
# FPS:  225.62151694459388
# 0 label_id: 0
# score: 0.8636775612831116
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6430376172065735
#     ymin: 0.4318082928657532
#     width: 0.3754499554634094
#     height: 0.6673540472984314
#   }
#   relative_keypoints {
#     x: 0.738156259059906
#     y: 0.671349823474884
#   }
#   relative_keypoints {
#     x: 0.9000970125198364
#     y: 0.6365768313407898
#   }
#   relative_keypoints {
#     x: 0.8272362947463989
#     y: 0.8470640778541565
#   }
#   relative_keypoints {
#     x: 0.8392212390899658
#     y: 0.9564200043678284
#   }
#   relative_keypoints {
#     x: 0.6631350517272949
#     y: 0.694540798664093
#   }
#   relative_keypoints {
#     x: 0.9962683320045471
#     y: 0.6184567809104919
#   }
# }
#
# FPS:  229.08427549292696
# 0 label_id: 0
# score: 0.872218906879425
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.647193431854248
#     ymin: 0.4360160231590271
#     width: 0.3734673261642456
#     height: 0.6638224720954895
#   }
#   relative_keypoints {
#     x: 0.7355671525001526
#     y: 0.6658219695091248
#   }
#   relative_keypoints {
#     x: 0.8975542783737183
#     y: 0.6487836241722107
#   }
#   relative_keypoints {
#     x: 0.8125092387199402
#     y: 0.851962149143219
#   }
#   relative_keypoints {
#     x: 0.8235998153686523
#     y: 0.9592379927635193
#   }
#   relative_keypoints {
#     x: 0.6699932813644409
#     y: 0.677814781665802
#   }
#   relative_keypoints {
#     x: 0.9997115731239319
#     y: 0.6368438601493835
#   }
# }
#
# FPS:  215.01532783103502
# 0 label_id: 0
# score: 0.8624274134635925
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6406347751617432
#     ymin: 0.43529295921325684
#     width: 0.37815308570861816
#     height: 0.6721508502960205
#   }
#   relative_keypoints {
#     x: 0.7325966358184814
#     y: 0.6660488247871399
#   }
#   relative_keypoints {
#     x: 0.8977409601211548
#     y: 0.6490040421485901
#   }
#   relative_keypoints {
#     x: 0.8131746649742126
#     y: 0.8528862595558167
#   }
#   relative_keypoints {
#     x: 0.8231837153434753
#     y: 0.9631528258323669
#   }
#   relative_keypoints {
#     x: 0.662195086479187
#     y: 0.6814461350440979
#   }
#   relative_keypoints {
#     x: 0.9982842206954956
#     y: 0.64076167345047
#   }
# }
#
# FPS:  224.4023326734792
# 0 label_id: 0
# score: 0.8731683492660522
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6393446326255798
#     ymin: 0.43685638904571533
#     width: 0.37523382902145386
#     height: 0.6669615507125854
#   }
#   relative_keypoints {
#     x: 0.7312675714492798
#     y: 0.6612192988395691
#   }
#   relative_keypoints {
#     x: 0.895531177520752
#     y: 0.653226912021637
#   }
#   relative_keypoints {
#     x: 0.8088957667350769
#     y: 0.8518553376197815
#   }
#   relative_keypoints {
#     x: 0.8173040747642517
#     y: 0.9602583050727844
#   }
#   relative_keypoints {
#     x: 0.6606937050819397
#     y: 0.6726625561714172
#   }
#   relative_keypoints {
#     x: 0.9939690828323364
#     y: 0.6482611298561096
#   }
# }
# FPS:  215.4682009657865
# 0 label_id: 0
# score: 0.8764155507087708
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.639119565486908
#     ymin: 0.4555721879005432
#     width: 0.37331312894821167
#     height: 0.6636034846305847
#   }
#   relative_keypoints {
#     x: 0.7243650555610657
#     y: 0.6787777543067932
#   }
#   relative_keypoints {
#     x: 0.8902416825294495
#     y: 0.6654005646705627
#   }
#   relative_keypoints {
#     x: 0.8031412959098816
#     y: 0.8698439002037048
#   }
#   relative_keypoints {
#     x: 0.8144695162773132
#     y: 0.9788838028907776
#   }
#   relative_keypoints {
#     x: 0.6583205461502075
#     y: 0.6905971169471741
#   }
#   relative_keypoints {
#     x: 0.9948626160621643
#     y: 0.6528179049491882
#   }
# }
#
# FPS:  195.05668976421896
# 0 label_id: 0
# score: 0.8747376203536987
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.640370786190033
#     ymin: 0.463617205619812
#     width: 0.36147624254226685
#     height: 0.6425818204879761
#   }
#   relative_keypoints {
#     x: 0.7245783805847168
#     y: 0.6784692406654358
#   }
#   relative_keypoints {
#     x: 0.8877084255218506
#     y: 0.656919538974762
#   }
#   relative_keypoints {
#     x: 0.8108847141265869
#     y: 0.850767195224762
#   }
#   relative_keypoints {
#     x: 0.8236544132232666
#     y: 0.9645498394966125
#   }
#   relative_keypoints {
#     x: 0.6533148884773254
#     y: 0.7099170088768005
#   }
#   relative_keypoints {
#     x: 0.9864625334739685
#     y: 0.6506487727165222
#   }
# }
#
# FPS:  206.05767624662246
# 0 label_id: 0
# score: 0.8617601990699768
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6416072249412537
#     ymin: 0.4661368131637573
#     width: 0.3541681170463562
#     height: 0.6295899152755737
#   }
#   relative_keypoints {
#     x: 0.7201105356216431
#     y: 0.6750380396842957
#   }
#   relative_keypoints {
#     x: 0.879217803478241
#     y: 0.6511855721473694
#   }
#   relative_keypoints {
#     x: 0.8009877800941467
#     y: 0.840440571308136
#   }
#   relative_keypoints {
#     x: 0.8149475455284119
#     y: 0.9548777937889099
#   }
#   relative_keypoints {
#     x: 0.65581214427948
#     y: 0.7119627594947815
#   }
#   relative_keypoints {
#     x: 0.9797396659851074
#     y: 0.6517639756202698
#   }
# }
#
# FPS:  211.15102698348772
# 0 label_id: 0
# score: 0.8735089898109436
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6432178020477295
#     ymin: 0.4745662808418274
#     width: 0.3722805976867676
#     height: 0.6617187857627869
#   }
#   relative_keypoints {
#     x: 0.7227876782417297
#     y: 0.6965826153755188
#   }
#   relative_keypoints {
#     x: 0.8913460373878479
#     y: 0.6629772782325745
#   }
#   relative_keypoints {
#     x: 0.8057741522789001
#     y: 0.8638744950294495
#   }
#   relative_keypoints {
#     x: 0.8218286633491516
#     y: 0.9813259243965149
#   }
#   relative_keypoints {
#     x: 0.6598267555236816
#     y: 0.7305511832237244
#   }
#   relative_keypoints {
#     x: 1.0013883113861084
#     y: 0.6611605286598206
#   }
# }
#
# FPS:  228.84679179397642
# 0 label_id: 0
# score: 0.8721290230751038
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6372830271720886
#     ymin: 0.47595542669296265
#     width: 0.366319477558136
#     height: 0.6511247754096985
#   }
#   relative_keypoints {
#     x: 0.7214372754096985
#     y: 0.7054480910301208
#   }
#   relative_keypoints {
#     x: 0.886216402053833
#     y: 0.6722802519798279
#   }
#   relative_keypoints {
#     x: 0.808541476726532
#     y: 0.8758113980293274
#   }
#   relative_keypoints {
#     x: 0.8222889304161072
#     y: 0.9842472672462463
#   }
#   relative_keypoints {
#     x: 0.6522247791290283
#     y: 0.7233983874320984
#   }
#   relative_keypoints {
#     x: 0.9860213398933411
#     y: 0.6515886187553406
#   }
# }
#
# FPS:  226.60889297098709
# 0 label_id: 0
# score: 0.8648095726966858
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6340934038162231
#     ymin: 0.46375370025634766
#     width: 0.37616443634033203
#     height: 0.6686305999755859
#   }
#   relative_keypoints {
#     x: 0.7141828536987305
#     y: 0.7003794312477112
#   }
#   relative_keypoints {
#     x: 0.8808566331863403
#     y: 0.6752590537071228
#   }
#   relative_keypoints {
#     x: 0.7924152612686157
#     y: 0.886745035648346
#   }
#   relative_keypoints {
#     x: 0.8078594207763672
#     y: 0.9927336573600769
#   }
#   relative_keypoints {
#     x: 0.6558324694633484
#     y: 0.7066469788551331
#   }
#   relative_keypoints {
#     x: 0.9928628206253052
#     y: 0.6501495242118835
#   }
# }
#
# FPS:  234.9618508767016
# 0 label_id: 0
# score: 0.8693078756332397
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6353750228881836
#     ymin: 0.47332340478897095
#     width: 0.3729064464569092
#     height: 0.6628281474113464
#   }
#   relative_keypoints {
#     x: 0.7116127610206604
#     y: 0.7046398520469666
#   }
#   relative_keypoints {
#     x: 0.8817482590675354
#     y: 0.6558133959770203
#   }
#   relative_keypoints {
#     x: 0.8014106154441833
#     y: 0.8659738898277283
#   }
#   relative_keypoints {
#     x: 0.8215131759643555
#     y: 0.9831814169883728
#   }
#   relative_keypoints {
#     x: 0.651212751865387
#     y: 0.741001546382904
#   }
#   relative_keypoints {
#     x: 0.9941312670707703
#     y: 0.6382783055305481
#   }
# }
#
# FPS:  236.63210155148096
# 0 label_id: 0
# score: 0.8679682016372681
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6363511681556702
#     ymin: 0.47161704301834106
#     width: 0.3689693808555603
#     height: 0.6558803915977478
#   }
#   relative_keypoints {
#     x: 0.709415078163147
#     y: 0.7004883885383606
#   }
#   relative_keypoints {
#     x: 0.8764630556106567
#     y: 0.667450487613678
#   }
#   relative_keypoints {
#     x: 0.7887868285179138
#     y: 0.8765679001808167
#   }
#   relative_keypoints {
#     x: 0.8068199753761292
#     y: 0.9865978360176086
#   }
#   relative_keypoints {
#     x: 0.6536006927490234
#     y: 0.7254757285118103
#   }
#   relative_keypoints {
#     x: 0.9922190308570862
#     y: 0.6523270010948181
#   }
# }
#
# FPS:  235.95319531953194
# 0 label_id: 0
# score: 0.8396884202957153
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6309955716133118
#     ymin: 0.46681666374206543
#     width: 0.3797284960746765
#     height: 0.6749508380889893
#   }
#   relative_keypoints {
#     x: 0.7122738361358643
#     y: 0.7008183598518372
#   }
#   relative_keypoints {
#     x: 0.8788997530937195
#     y: 0.6604378819465637
#   }
#   relative_keypoints {
#     x: 0.7940916419029236
#     y: 0.8783370852470398
#   }
#   relative_keypoints {
#     x: 0.8124858140945435
#     y: 0.9933963418006897
#   }
#   relative_keypoints {
#     x: 0.6553272008895874
#     y: 0.731240451335907
#   }
#   relative_keypoints {
#     x: 0.9884986877441406
#     y: 0.6495316624641418
#   }
# }
#
# FPS:  227.75325803649
# 0 label_id: 0
# score: 0.8483745455741882
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.637686550617218
#     ymin: 0.47121310234069824
#     width: 0.3615512251853943
#     height: 0.6426935195922852
#   }
#   relative_keypoints {
#     x: 0.7117586135864258
#     y: 0.6946240067481995
#   }
#   relative_keypoints {
#     x: 0.8726552128791809
#     y: 0.6589164137840271
#   }
#   relative_keypoints {
#     x: 0.7904874086380005
#     y: 0.8632513880729675
#   }
#   relative_keypoints {
#     x: 0.8088566064834595
#     y: 0.9745878577232361
#   }
#   relative_keypoints {
#     x: 0.6564810276031494
#     y: 0.7231032252311707
#   }
#   relative_keypoints {
#     x: 0.9838783144950867
#     y: 0.6424567103385925
#   }
# }
#
# FPS:  232.29419583517944
# 0 label_id: 0
# score: 0.8610718846321106
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6367335319519043
#     ymin: 0.4690391421318054
#     width: 0.3650566339492798
#     height: 0.6489282250404358
#   }
#   relative_keypoints {
#     x: 0.7087799310684204
#     y: 0.7008128762245178
#   }
#   relative_keypoints {
#     x: 0.8722638487815857
#     y: 0.6759843230247498
#   }
#   relative_keypoints {
#     x: 0.78354412317276
#     y: 0.884375274181366
#   }
#   relative_keypoints {
#     x: 0.8012700080871582
#     y: 0.9874634146690369
#   }
#   relative_keypoints {
#     x: 0.6557759046554565
#     y: 0.7090558409690857
#   }
#   relative_keypoints {
#     x: 0.9889907836914062
#     y: 0.647433340549469
#   }
# }
#
# FPS:  226.30322650264378
# 0 label_id: 0
# score: 0.8520993590354919
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6327124238014221
#     ymin: 0.4667179584503174
#     width: 0.37497133016586304
#     height: 0.6665034294128418
#   }
#   relative_keypoints {
#     x: 0.7109180688858032
#     y: 0.7042306065559387
#   }
#   relative_keypoints {
#     x: 0.8722139596939087
#     y: 0.6795617938041687
#   }
#   relative_keypoints {
#     x: 0.7815593481063843
#     y: 0.8931507468223572
#   }
#   relative_keypoints {
#     x: 0.7990966439247131
#     y: 0.9962716698646545
#   }
#   relative_keypoints {
#     x: 0.6614540815353394
#     y: 0.7086943984031677
#   }
#   relative_keypoints {
#     x: 0.9875937700271606
#     y: 0.6552076935768127
#   }
# }
# FPS:  213.30946447642782
# 0 label_id: 0
# score: 0.8691399693489075
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.632817804813385
#     ymin: 0.46482497453689575
#     width: 0.3665369749069214
#     height: 0.6515793204307556
#   }
#   relative_keypoints {
#     x: 0.7058016061782837
#     y: 0.6831911206245422
#   }
#   relative_keypoints {
#     x: 0.8683022260665894
#     y: 0.6825032830238342
#   }
#   relative_keypoints {
#     x: 0.7755683064460754
#     y: 0.8774648308753967
#   }
#   relative_keypoints {
#     x: 0.7905041575431824
#     y: 0.9846293330192566
#   }
#   relative_keypoints {
#     x: 0.6532921195030212
#     y: 0.6936865448951721
#   }
#   relative_keypoints {
#     x: 0.9845590591430664
#     y: 0.6698756814002991
#   }
# }
#
# FPS:  225.93751346692522
# 0 label_id: 0
# score: 0.8712319731712341
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6327415108680725
#     ymin: 0.4651299715042114
#     width: 0.3658093810081482
#     height: 0.6502867937088013
#   }
#   relative_keypoints {
#     x: 0.7045900225639343
#     y: 0.689048707485199
#   }
#   relative_keypoints {
#     x: 0.8667994141578674
#     y: 0.6831098198890686
#   }
#   relative_keypoints {
#     x: 0.7755306363105774
#     y: 0.8826516270637512
#   }
#   relative_keypoints {
#     x: 0.7922253012657166
#     y: 0.9871341586112976
#   }
#   relative_keypoints {
#     x: 0.6534092426300049
#     y: 0.6974634528160095
#   }
#   relative_keypoints {
#     x: 0.984032928943634
#     y: 0.6624243855476379
#   }
# }
#
# FPS:  242.96495394774954
# 0 label_id: 0
# score: 0.8635215759277344
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6326113343238831
#     ymin: 0.4679534435272217
#     width: 0.3624104857444763
#     height: 0.6442446708679199
#   }
#   relative_keypoints {
#     x: 0.7093551158905029
#     y: 0.6857406497001648
#   }
#   relative_keypoints {
#     x: 0.8702387809753418
#     y: 0.6851939558982849
#   }
#   relative_keypoints {
#     x: 0.7819791436195374
#     y: 0.876964271068573
#   }
#   relative_keypoints {
#     x: 0.7951902747154236
#     y: 0.9818945527076721
#   }
#   relative_keypoints {
#     x: 0.6511059999465942
#     y: 0.6940764784812927
#   }
#   relative_keypoints {
#     x: 0.9803662896156311
#     y: 0.6698160767555237
#   }
# }
#
# FPS:  223.97095103326748
# 0 label_id: 0
# score: 0.8733941316604614
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6386686563491821
#     ymin: 0.4685665965080261
#     width: 0.3587348461151123
#     height: 0.6377103924751282
#   }
#   relative_keypoints {
#     x: 0.7152957916259766
#     y: 0.6816549897193909
#   }
#   relative_keypoints {
#     x: 0.8766980767250061
#     y: 0.6699425578117371
#   }
#   relative_keypoints {
#     x: 0.7942268252372742
#     y: 0.855656087398529
#   }
#   relative_keypoints {
#     x: 0.8086252808570862
#     y: 0.9663457274436951
#   }
#   relative_keypoints {
#     x: 0.6529276371002197
#     y: 0.7051711678504944
#   }
#   relative_keypoints {
#     x: 0.9856286644935608
#     y: 0.6596435904502869
#   }
# }
#
# FPS:  241.84420227180996
# 0 label_id: 0
# score: 0.8773860931396484
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.639339029788971
#     ymin: 0.4671199321746826
#     width: 0.3600669503211975
#     height: 0.6400787830352783
#   }
#   relative_keypoints {
#     x: 0.7116386294364929
#     y: 0.6861351132392883
#   }
#   relative_keypoints {
#     x: 0.8721837401390076
#     y: 0.6761074662208557
#   }
#   relative_keypoints {
#     x: 0.7848737239837646
#     y: 0.8666204810142517
#   }
#   relative_keypoints {
#     x: 0.8009127378463745
#     y: 0.9725950360298157
#   }
#   relative_keypoints {
#     x: 0.6568153500556946
#     y: 0.7001752257347107
#   }
#   relative_keypoints {
#     x: 0.9879698753356934
#     y: 0.6590881943702698
#   }
# }
#
# FPS:  235.42343960484956
# 0 label_id: 0
# score: 0.8824993371963501
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6388418674468994
#     ymin: 0.46339404582977295
#     width: 0.35947853326797485
#     height: 0.6390331983566284
#   }
#   relative_keypoints {
#     x: 0.7098954916000366
#     y: 0.6837411522865295
#   }
#   relative_keypoints {
#     x: 0.8700926899909973
#     y: 0.6662082076072693
#   }
#   relative_keypoints {
#     x: 0.7840380668640137
#     y: 0.8607998490333557
#   }
#   relative_keypoints {
#     x: 0.800521731376648
#     y: 0.9673786759376526
#   }
#   relative_keypoints {
#     x: 0.6564423441886902
#     y: 0.701880156993866
#   }
#   relative_keypoints {
#     x: 0.9845614433288574
#     y: 0.6507232785224915
#   }
# }
#
# FPS:  215.97857878475799
# 0 label_id: 0
# score: 0.8788981437683105
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6384398341178894
#     ymin: 0.4747251868247986
#     width: 0.3698424696922302
#     height: 0.6573801636695862
#   }
#   relative_keypoints {
#     x: 0.7206223607063293
#     y: 0.6992142796516418
#   }
#   relative_keypoints {
#     x: 0.8854668736457825
#     y: 0.6659806370735168
#   }
#   relative_keypoints {
#     x: 0.8044257760047913
#     y: 0.8687716126441956
#   }
#   relative_keypoints {
#     x: 0.8190826773643494
#     y: 0.9823513627052307
#   }
#   relative_keypoints {
#     x: 0.6568032503128052
#     y: 0.7262702584266663
#   }
#   relative_keypoints {
#     x: 0.9899603128433228
#     y: 0.6572950482368469
#   }
# }
#
# FPS:  217.40030062717048
# 0 label_id: 0
# score: 0.8574183583259583
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6380202770233154
#     ymin: 0.47404974699020386
#     width: 0.3696479797363281
#     height: 0.6570373177528381
#   }
#   relative_keypoints {
#     x: 0.7244613766670227
#     y: 0.6970217823982239
#   }
#   relative_keypoints {
#     x: 0.8905748724937439
#     y: 0.6616926789283752
#   }
#   relative_keypoints {
#     x: 0.8128190636634827
#     y: 0.8671899437904358
#   }
#   relative_keypoints {
#     x: 0.8265535831451416
#     y: 0.9820167422294617
#   }
#   relative_keypoints {
#     x: 0.6539289951324463
#     y: 0.7291653752326965
#   }
#   relative_keypoints {
#     x: 0.9883017539978027
#     y: 0.6544075608253479
#   }
# }
#
# FPS:  217.96518214415633
# 0 label_id: 0
# score: 0.8795614242553711
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6345362067222595
#     ymin: 0.46135401725769043
#     width: 0.37040406465530396
#     height: 0.6584305763244629
#   }
#   relative_keypoints {
#     x: 0.7171310782432556
#     y: 0.6759770512580872
#   }
#   relative_keypoints {
#     x: 0.8827100992202759
#     y: 0.6594277024269104
#   }
#   relative_keypoints {
#     x: 0.8003280162811279
#     y: 0.8512852787971497
#   }
#   relative_keypoints {
#     x: 0.8139363527297974
#     y: 0.9699873328208923
#   }
#   relative_keypoints {
#     x: 0.6507866382598877
#     y: 0.7081066966056824
#   }
#   relative_keypoints {
#     x: 0.9881207942962646
#     y: 0.659674346446991
#   }
# }
#
# FPS:  233.09458708458374
# 0 label_id: 0
# score: 0.8631193041801453
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6317934989929199
#     ymin: 0.44779980182647705
#     width: 0.3676111698150635
#     height: 0.6534684896469116
#   }
#   relative_keypoints {
#     x: 0.7200838327407837
#     y: 0.6723588109016418
#   }
#   relative_keypoints {
#     x: 0.8821484446525574
#     y: 0.6502887606620789
#   }
#   relative_keypoints {
#     x: 0.80390465259552
#     y: 0.8505249619483948
#   }
#   relative_keypoints {
#     x: 0.8151497840881348
#     y: 0.9614318013191223
#   }
#   relative_keypoints {
#     x: 0.64895099401474
#     y: 0.6963555216789246
#   }
#   relative_keypoints {
#     x: 0.9802350401878357
#     y: 0.6416903138160706
#   }
# }
#
# FPS:  231.48650587780782
# 0 label_id: 0
# score: 0.8772940635681152
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6323737502098083
#     ymin: 0.4272184371948242
#     width: 0.38207775354385376
#     height: 0.6791315078735352
#   }
#   relative_keypoints {
#     x: 0.7292940616607666
#     y: 0.6611036658287048
#   }
#   relative_keypoints {
#     x: 0.8936229348182678
#     y: 0.6494504809379578
#   }
#   relative_keypoints {
#     x: 0.8101063966751099
#     y: 0.8544110655784607
#   }
#   relative_keypoints {
#     x: 0.8179652094841003
#     y: 0.961269199848175
#   }
#   relative_keypoints {
#     x: 0.6551592946052551
#     y: 0.6671590209007263
#   }
#   relative_keypoints {
#     x: 0.9900708794593811
#     y: 0.6374912858009338
#   }
# }
#
# FPS:  224.16247127358238
# 0 label_id: 0
# score: 0.8943893909454346
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6319045424461365
#     ymin: 0.43389439582824707
#     width: 0.3905636668205261
#     height: 0.6942121982574463
#   }
#   relative_keypoints {
#     x: 0.7240260243415833
#     y: 0.6732826828956604
#   }
#   relative_keypoints {
#     x: 0.8947146534919739
#     y: 0.6484381556510925
#   }
#   relative_keypoints {
#     x: 0.8091089129447937
#     y: 0.8625914454460144
#   }
#   relative_keypoints {
#     x: 0.8216475248336792
#     y: 0.9756289124488831
#   }
#   relative_keypoints {
#     x: 0.6533554196357727
#     y: 0.6922207474708557
#   }
#   relative_keypoints {
#     x: 1.0010088682174683
#     y: 0.636221706867218
#   }
# }
#
# FPS:  221.44047304788555
# 0 label_id: 0
# score: 0.8699706792831421
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6339080929756165
#     ymin: 0.4323522448539734
#     width: 0.387423574924469
#     height: 0.6886294484138489
#   }
#   relative_keypoints {
#     x: 0.72487872838974
#     y: 0.6736927628517151
#   }
#   relative_keypoints {
#     x: 0.8913164138793945
#     y: 0.6396580338478088
#   }
#   relative_keypoints {
#     x: 0.8092267513275146
#     y: 0.8546248078346252
#   }
#   relative_keypoints {
#     x: 0.8242297768592834
#     y: 0.9686550498008728
#   }
#   relative_keypoints {
#     x: 0.6588237285614014
#     y: 0.7000676989555359
#   }
#   relative_keypoints {
#     x: 0.9978693127632141
#     y: 0.6282255053520203
#   }
# }
#
# FPS:  228.1496953872933
# 0 label_id: 0
# score: 0.8740213513374329
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.634880006313324
#     ymin: 0.44033336639404297
#     width: 0.38211578130722046
#     height: 0.6791934967041016
#   }
#   relative_keypoints {
#     x: 0.7276816964149475
#     y: 0.6676669716835022
#   }
#   relative_keypoints {
#     x: 0.8890343308448792
#     y: 0.6298978924751282
#   }
#   relative_keypoints {
#     x: 0.8135286569595337
#     y: 0.8361839652061462
#   }
#   relative_keypoints {
#     x: 0.8291947245597839
#     y: 0.9585167765617371
#   }
#   relative_keypoints {
#     x: 0.6620582342147827
#     y: 0.7112240195274353
#   }
#   relative_keypoints {
#     x: 0.9924222826957703
#     y: 0.6278032660484314
#   }
# }
#
# FPS:  231.65271180824035
# 0 label_id: 0
# score: 0.8687433004379272
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6342911124229431
#     ymin: 0.43948620557785034
#     width: 0.3835030198097229
#     height: 0.6816557049751282
#   }
#   relative_keypoints {
#     x: 0.7280895113945007
#     y: 0.6660788655281067
#   }
#   relative_keypoints {
#     x: 0.8904392123222351
#     y: 0.6303195357322693
#   }
#   relative_keypoints {
#     x: 0.8132340908050537
#     y: 0.8387261033058167
#   }
#   relative_keypoints {
#     x: 0.8279451131820679
#     y: 0.9606099724769592
#   }
#   relative_keypoints {
#     x: 0.6605184078216553
#     y: 0.7107382416725159
#   }
#   relative_keypoints {
#     x: 0.9906917810440063
#     y: 0.63302081823349
#   }
# }
#
# FPS:  154.65152464879614
# 0 label_id: 0
# score: 0.858781099319458
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6378752589225769
#     ymin: 0.434961199760437
#     width: 0.37415415048599243
#     height: 0.6650782823562622
#   }
#   relative_keypoints {
#     x: 0.7306764721870422
#     y: 0.6588414311408997
#   }
#   relative_keypoints {
#     x: 0.8923934102058411
#     y: 0.6235013604164124
#   }
#   relative_keypoints {
#     x: 0.8180081248283386
#     y: 0.8268824219703674
#   }
#   relative_keypoints {
#     x: 0.8314422965049744
#     y: 0.9467999339103699
#   }
#   relative_keypoints {
#     x: 0.6594868898391724
#     y: 0.7034137845039368
#   }
#   relative_keypoints {
#     x: 0.9899525046348572
#     y: 0.6235617995262146
#   }
# }
#
# FPS:  202.63317068457414
# 0 label_id: 0
# score: 0.8771584033966064
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.638576090335846
#     ymin: 0.43733370304107666
#     width: 0.37520450353622437
#     height: 0.6669446229934692
#   }
#   relative_keypoints {
#     x: 0.7324116230010986
#     y: 0.6626959443092346
#   }
#   relative_keypoints {
#     x: 0.8938670754432678
#     y: 0.6266807913780212
#   }
#   relative_keypoints {
#     x: 0.8202692866325378
#     y: 0.8307810425758362
#   }
#   relative_keypoints {
#     x: 0.833514928817749
#     y: 0.9498808979988098
#   }
#   relative_keypoints {
#     x: 0.6605794429779053
#     y: 0.7059895396232605
#   }
#   relative_keypoints {
#     x: 0.9916777610778809
#     y: 0.6249839663505554
#   }
# }
#
# FPS:  232.28133133964667
# 0 label_id: 0
# score: 0.8801450729370117
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6361226439476013
#     ymin: 0.4335637092590332
#     width: 0.36857694387435913
#     height: 0.6551632881164551
#   }
#   relative_keypoints {
#     x: 0.7311344146728516
#     y: 0.648658812046051
#   }
#   relative_keypoints {
#     x: 0.8918129205703735
#     y: 0.622160017490387
#   }
#   relative_keypoints {
#     x: 0.8198341727256775
#     y: 0.8133650422096252
#   }
#   relative_keypoints {
#     x: 0.8302335143089294
#     y: 0.932116687297821
#   }
#   relative_keypoints {
#     x: 0.6539791822433472
#     y: 0.6895958781242371
#   }
#   relative_keypoints {
#     x: 0.9830936193466187
#     y: 0.6251532435417175
#   }
# }
#
# FPS:  229.39750601618903
# 0 label_id: 0
# score: 0.8817701935768127
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.6369783878326416
#     ymin: 0.424899160861969
#     width: 0.3681790828704834
#     height: 0.6544565558433533
#   }
#   relative_keypoints {
#     x: 0.730940043926239
#     y: 0.6402944922447205
#   }
#   relative_keypoints {
#     x: 0.8915094137191772
#     y: 0.6173728108406067
#   }
#   relative_keypoints {
#     x: 0.8175072073936462
#     y: 0.8081451058387756
#   }
#   relative_keypoints {
#     x: 0.8275102376937866
#     y: 0.9245093464851379
#   }
#   relative_keypoints {
#     x: 0.6554672122001648
#     y: 0.674643337726593
#   }
#   relative_keypoints {
#     x: 0.9839193820953369
#     y: 0.6176214814186096
#   }
# }
#
# FPS:  222.9589623644482
# 0 label_id: 0
# score: 0.8797200918197632
# location_data {
# ...
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.008968527428805828
#     ymin: 0.5535223484039307
#     width: 0.21771886944770813
#     height: 0.38705605268478394
#   }
#   relative_keypoints {
#     x: 0.09204813092947006
#     y: 0.6652719378471375
#   }
#   relative_keypoints {
#     x: 0.18177445232868195
#     y: 0.6841908097267151
#   }
#   relative_keypoints {
#     x: 0.14527206122875214
#     y: 0.7770302891731262
#   }
#   relative_keypoints {
#     x: 0.13457253575325012
#     y: 0.846752941608429
#   }
#   relative_keypoints {
#     x: 0.01606227643787861
#     y: 0.6696717143058777
#   }
#   relative_keypoints {
#     x: 0.20651131868362427
#     y: 0.7020774483680725
#   }
# }
#
# FPS:  256.3442121989977
# 0 label_id: 0
# score: 0.86757493019104
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.009977431036531925
#     ymin: 0.5534546971321106
#     width: 0.21658368408679962
#     height: 0.3850381374359131
#   }
#   relative_keypoints {
#     x: 0.09222772717475891
#     y: 0.6630226969718933
#   }
#   relative_keypoints {
#     x: 0.18161509931087494
#     y: 0.6829169392585754
#   }
#   relative_keypoints {
#     x: 0.14438696205615997
#     y: 0.7743162512779236
#   }
#   relative_keypoints {
#     x: 0.13364160060882568
#     y: 0.8440518975257874
#   }
#   relative_keypoints {
#     x: 0.017331289127469063
#     y: 0.6679690480232239
#   }
#   relative_keypoints {
#     x: 0.2067587524652481
#     y: 0.7024314999580383
#   }
# }
#
# FPS:  260.7587193036991
# 0 label_id: 0
# score: 0.8639470338821411
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.009002969600260258
#     ymin: 0.5541412830352783
#     width: 0.21676306426525116
#     height: 0.3853568434715271
#   }
#   relative_keypoints {
#     x: 0.09116236865520477
#     y: 0.6631342768669128
#   }
#   relative_keypoints {
#     x: 0.18072666227817535
#     y: 0.6843557953834534
#   }
#   relative_keypoints {
#     x: 0.142788365483284
#     y: 0.7756941914558411
#   }
#   relative_keypoints {
#     x: 0.1317066103219986
#     y: 0.8455629944801331
#   }
#   relative_keypoints {
#     x: 0.016309339553117752
#     y: 0.6670867800712585
#   }
#   relative_keypoints {
#     x: 0.20608414709568024
#     y: 0.7047091126441956
#   }
# }
#
# FPS:  248.1983549322445
# 0 label_id: 0
# score: 0.8646699786186218
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.009982415474951267
#     ymin: 0.556585967540741
#     width: 0.2145225554704666
#     height: 0.38137388229370117
#   }
#   relative_keypoints {
#     x: 0.0914149060845375
#     y: 0.6643884778022766
#   }
#   relative_keypoints {
#     x: 0.18028424680233002
#     y: 0.6850090622901917
#   }
#   relative_keypoints {
#     x: 0.14312875270843506
#     y: 0.7747570872306824
#   }
#   relative_keypoints {
#     x: 0.13230274617671967
#     y: 0.8440230488777161
#   }
#   relative_keypoints {
#     x: 0.016932109370827675
#     y: 0.6696078181266785
#   }
#   relative_keypoints {
#     x: 0.2053138166666031
#     y: 0.7055526375770569
#   }
# }
#
# FPS:  260.33790577866057
# 0 label_id: 0
# score: 0.862678587436676
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.010582886636257172
#     ymin: 0.5563191175460815
#     width: 0.21503949165344238
#     height: 0.3822929263114929
#   }
#   relative_keypoints {
#     x: 0.09243157505989075
#     y: 0.6653209328651428
#   }
#   relative_keypoints {
#     x: 0.18066154420375824
#     y: 0.685512363910675
#   }
#   relative_keypoints {
#     x: 0.1437760293483734
#     y: 0.7763996720314026
#   }
#   relative_keypoints {
#     x: 0.13311520218849182
#     y: 0.8452566266059875
#   }
#   relative_keypoints {
#     x: 0.018535586073994637
#     y: 0.6693781018257141
#   }
#   relative_keypoints {
#     x: 0.20588845014572144
#     y: 0.7046851515769958
#   }
# }
#
# FPS:  253.2792270531401
# 0 label_id: 0
# score: 0.8667129874229431
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.012205012142658234
#     ymin: 0.5577253699302673
#     width: 0.21300432085990906
#     height: 0.3786747455596924
#   }
#   relative_keypoints {
#     x: 0.09412413090467453
#     y: 0.6664031147956848
#   }
#   relative_keypoints {
#     x: 0.1807233691215515
#     y: 0.6865412592887878
#   }
#   relative_keypoints {
#     x: 0.14495740830898285
#     y: 0.7767711281776428
#   }
#   relative_keypoints {
#     x: 0.13418346643447876
#     y: 0.8442654013633728
#   }
#   relative_keypoints {
#     x: 0.020475102588534355
#     y: 0.6688938736915588
#   }
#   relative_keypoints {
#     x: 0.20499874651432037
#     y: 0.7044745087623596
#   }
# }
#
# FPS:  251.2461962381694
# 0 label_id: 0
# score: 0.8621854782104492
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.012284422293305397
#     ymin: 0.554437518119812
#     width: 0.21442130208015442
#     height: 0.38119417428970337
#   }
#   relative_keypoints {
#     x: 0.09441343694925308
#     y: 0.6644932627677917
#   }
#   relative_keypoints {
#     x: 0.18155531585216522
#     y: 0.6855980753898621
#   }
#   relative_keypoints {
#     x: 0.1448574811220169
#     y: 0.7771778702735901
#   }
#   relative_keypoints {
#     x: 0.13380153477191925
#     y: 0.8441463112831116
#   }
#   relative_keypoints {
#     x: 0.0204974003136158
#     y: 0.6638550162315369
#   }
#   relative_keypoints {
#     x: 0.20614877343177795
#     y: 0.7018147110939026
#   }
# }
#
# FPS:  241.024250086197
# 0 label_id: 0
# score: 0.8717116713523865
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.014036810025572777
#     ymin: 0.5562350153923035
#     width: 0.2121618241071701
#     height: 0.3771771192550659
#   }
#   relative_keypoints {
#     x: 0.09604371339082718
#     y: 0.6636187434196472
#   }
#   relative_keypoints {
#     x: 0.18187864124774933
#     y: 0.6848370432853699
#   }
#   relative_keypoints {
#     x: 0.1458689421415329
#     y: 0.7742634415626526
#   }
#   relative_keypoints {
#     x: 0.1347428858280182
#     y: 0.8412205576896667
#   }
#   relative_keypoints {
#     x: 0.02255975268781185
#     y: 0.6651135087013245
#   }
#   relative_keypoints {
#     x: 0.20556743443012238
#     y: 0.703074038028717
#   }
# }
#
# FPS:  222.22655504927414
# 0 label_id: 0
# score: 0.8709039688110352
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.014232791028916836
#     ymin: 0.5504078269004822
#     width: 0.2141679972410202
#     height: 0.3807438611984253
#   }
#   relative_keypoints {
#     x: 0.09353816509246826
#     y: 0.6591293215751648
#   }
#   relative_keypoints {
#     x: 0.18154174089431763
#     y: 0.6794795393943787
#   }
#   relative_keypoints {
#     x: 0.1430322378873825
#     y: 0.7705430388450623
#   }
#   relative_keypoints {
#     x: 0.1329769790172577
#     y: 0.8382824063301086
#   }
#   relative_keypoints {
#     x: 0.022460589185357094
#     y: 0.6614317297935486
#   }
#   relative_keypoints {
#     x: 0.20921391248703003
#     y: 0.697817862033844
#   }
# }
#
# FPS:  231.15480848718656
# 0 label_id: 0
# score: 0.866173505783081
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.012008380144834518
#     ymin: 0.5501978397369385
#     width: 0.21717369556427002
#     height: 0.3860871195793152
#   }
#   relative_keypoints {
#     x: 0.09484370052814484
#     y: 0.6603510975837708
#   }
#   relative_keypoints {
#     x: 0.18298378586769104
#     y: 0.681370198726654
#   }
#   relative_keypoints {
#     x: 0.14526386559009552
#     y: 0.7738638520240784
#   }
#   relative_keypoints {
#     x: 0.13419681787490845
#     y: 0.8426020741462708
#   }
#   relative_keypoints {
#     x: 0.020863911136984825
#     y: 0.6615162491798401
#   }
#   relative_keypoints {
#     x: 0.20827573537826538
#     y: 0.6996856331825256
#   }
# }
#
# FPS:  229.46025493735982
# 0 label_id: 0
# score: 0.8706501722335815
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.013451160863041878
#     ymin: 0.549609899520874
#     width: 0.21615968644618988
#     height: 0.38428443670272827
#   }
#   relative_keypoints {
#     x: 0.09552431851625443
#     y: 0.6595984101295471
#   }
#   relative_keypoints {
#     x: 0.18316195905208588
#     y: 0.6790489554405212
#   }
#   relative_keypoints {
#     x: 0.14610913395881653
#     y: 0.7712584137916565
#   }
#   relative_keypoints {
#     x: 0.13555361330509186
#     y: 0.8399527668952942
#   }
#   relative_keypoints {
#     x: 0.022282034158706665
#     y: 0.6625338196754456
#   }
#   relative_keypoints {
#     x: 0.2088462859392166
#     y: 0.6972885727882385
#   }
# }
#
# FPS:  239.16884301761988
# 0 label_id: 0
# score: 0.8762973546981812
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.014481371268630028
#     ymin: 0.5518825054168701
#     width: 0.2145942896604538
#     height: 0.3815017342567444
#   }
#   relative_keypoints {
#     x: 0.09560565650463104
#     y: 0.6601117253303528
#   }
#   relative_keypoints {
#     x: 0.18279069662094116
#     y: 0.6786208748817444
#   }
#   relative_keypoints {
#     x: 0.1460111141204834
#     y: 0.7689324021339417
#   }
#   relative_keypoints {
#     x: 0.13588184118270874
#     y: 0.8382630944252014
#   }
#   relative_keypoints {
#     x: 0.02320345863699913
#     y: 0.6665048003196716
#   }
#   relative_keypoints {
#     x: 0.20884357392787933
#     y: 0.6991119980812073
#   }
# }
#
# FPS:  232.4486810019951
# 0 label_id: 0
# score: 0.8804706931114197
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.01543433591723442
#     ymin: 0.5529502034187317
#     width: 0.21417447924613953
#     height: 0.3807551860809326
#   }
#   relative_keypoints {
#     x: 0.09657316654920578
#     y: 0.6611097455024719
#   }
#   relative_keypoints {
#     x: 0.18384605646133423
#     y: 0.6773108839988708
#   }
#   relative_keypoints {
#     x: 0.1482335925102234
#     y: 0.7681686282157898
#   }
#   relative_keypoints {
#     x: 0.13866642117500305
#     y: 0.8381372094154358
#   }
#   relative_keypoints {
#     x: 0.02386811189353466
#     y: 0.6705827116966248
#   }
#   relative_keypoints {
#     x: 0.20948348939418793
#     y: 0.6976433396339417
#   }
# }
#
# FPS:  247.7585208813279
# 0 label_id: 0
# score: 0.8853175044059753
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.01662897691130638
#     ymin: 0.5557403564453125
#     width: 0.2134166657924652
#     height: 0.3794075846672058
#   }
#   relative_keypoints {
#     x: 0.09645789861679077
#     y: 0.6643379330635071
#   }
#   relative_keypoints {
#     x: 0.18338191509246826
#     y: 0.6798047423362732
#   }
#   relative_keypoints {
#     x: 0.14712998270988464
#     y: 0.7712449431419373
#   }
#   relative_keypoints {
#     x: 0.137633815407753
#     y: 0.8400784134864807
#   }
#   relative_keypoints {
#     x: 0.024603506550192833
#     y: 0.6726494431495667
#   }
#   relative_keypoints {
#     x: 0.210443913936615
#     y: 0.7001555562019348
#   }
# }
#
# FPS:  243.41616853345715
# 0 label_id: 0
# score: 0.8779860734939575
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.015147754922509193
#     ymin: 0.5528981685638428
#     width: 0.2160133421421051
#     height: 0.3840239644050598
#   }
#   relative_keypoints {
#     x: 0.09515814483165741
#     y: 0.6639919877052307
#   }
#   relative_keypoints {
#     x: 0.1833384484052658
#     y: 0.6781882643699646
#   }
#   relative_keypoints {
#     x: 0.146540567278862
#     y: 0.7718492150306702
#   }
#   relative_keypoints {
#     x: 0.13732758164405823
#     y: 0.8414116501808167
#   }
#   relative_keypoints {
#     x: 0.023125015199184418
#     y: 0.6722479462623596
#   }
#   relative_keypoints {
#     x: 0.21144996583461761
#     y: 0.6973788142204285
#   }
# }
#
# FPS:  262.25873819796163
# 0 label_id: 0
# score: 0.8789322972297668
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.015760742127895355
#     ymin: 0.5528101325035095
#     width: 0.2155667245388031
#     height: 0.38323044776916504
#   }
#   relative_keypoints {
#     x: 0.0963800698518753
#     y: 0.6617498993873596
#   }
#   relative_keypoints {
#     x: 0.18432240188121796
#     y: 0.6761893630027771
#   }
#   relative_keypoints {
#     x: 0.148281067609787
#     y: 0.7683066725730896
#   }
#   relative_keypoints {
#     x: 0.1393052190542221
#     y: 0.8394977450370789
#   }
#   relative_keypoints {
#     x: 0.0243576318025589
#     y: 0.6728703379631042
#   }
#   relative_keypoints {
#     x: 0.21164216101169586
#     y: 0.6967248320579529
#   }
# }
#
# FPS:  248.83151400094923
# 0 label_id: 0
# score: 0.8892308473587036
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.017227061092853546
#     ymin: 0.5546276569366455
#     width: 0.21336036920547485
#     height: 0.3793075680732727
#   }
#   relative_keypoints {
#     x: 0.0965699851512909
#     y: 0.6638117432594299
#   }
#   relative_keypoints {
#     x: 0.18369431793689728
#     y: 0.6785207390785217
#   }
#   relative_keypoints {
#     x: 0.1477612853050232
#     y: 0.7703489661216736
#   }
#   relative_keypoints {
#     x: 0.13861888647079468
#     y: 0.8390255570411682
#   }
#   relative_keypoints {
#     x: 0.02490885555744171
#     y: 0.6719129681587219
#   }
#   relative_keypoints {
#     x: 0.21141526103019714
#     y: 0.6977151036262512
#   }
# }
#
# FPS:  236.5253482208312
# 0 label_id: 0
# score: 0.889535665512085
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.017341792583465576
#     ymin: 0.5546260476112366
#     width: 0.21391063928604126
#     height: 0.38028573989868164
#   }
#   relative_keypoints {
#     x: 0.0957978293299675
#     y: 0.6629547476768494
#   }
#   relative_keypoints {
#     x: 0.1837741732597351
#     y: 0.6785984635353088
#   }
#   relative_keypoints {
#     x: 0.14657877385616302
#     y: 0.7694678902626038
#   }
#   relative_keypoints {
#     x: 0.13763019442558289
#     y: 0.8390960097312927
#   }
#   relative_keypoints {
#     x: 0.024889474734663963
#     y: 0.6725721955299377
#   }
#   relative_keypoints {
#     x: 0.21284537017345428
#     y: 0.6998276114463806
#   }
# }
#
# FPS:  259.87013630731104
# 0 label_id: 0
# score: 0.8887151479721069
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.017786193639039993
#     ymin: 0.5549132823944092
#     width: 0.21264231204986572
#     height: 0.37803107500076294
#   }
#   relative_keypoints {
#     x: 0.09519877284765244
#     y: 0.6627050042152405
#   }
#   relative_keypoints {
#     x: 0.18348373472690582
#     y: 0.678638756275177
#   }
#   relative_keypoints {
#     x: 0.1461479514837265
#     y: 0.7686282992362976
#   }
#   relative_keypoints {
#     x: 0.13738839328289032
#     y: 0.8378010392189026
#   }
#   relative_keypoints {
#     x: 0.024524787440896034
#     y: 0.6726172566413879
#   }
#   relative_keypoints {
#     x: 0.21283936500549316
#     y: 0.6996050477027893
#   }
# }
# FPS:  258.54059051963264
# 0 label_id: 0
# score: 0.8885704278945923
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.01609129272401333
#     ymin: 0.5550327301025391
#     width: 0.21436479687690735
#     height: 0.38109368085861206
#   }
#   relative_keypoints {
#     x: 0.09695755690336227
#     y: 0.6628161072731018
#   }
#   relative_keypoints {
#     x: 0.18489481508731842
#     y: 0.6789559721946716
#   }
#   relative_keypoints {
#     x: 0.14927047491073608
#     y: 0.7688341736793518
#   }
#   relative_keypoints {
#     x: 0.13987940549850464
#     y: 0.83976811170578
#   }
#   relative_keypoints {
#     x: 0.023746952414512634
#     y: 0.674084484577179
#   }
#   relative_keypoints {
#     x: 0.2110491693019867
#     y: 0.6999815106391907
#   }
# }
#
# FPS:  270.19931714230495
# 0 label_id: 0
# score: 0.8852955102920532
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.017248881980776787
#     ymin: 0.5564670562744141
#     width: 0.2118586301803589
#     height: 0.3766377568244934
#   }
#   relative_keypoints {
#     x: 0.09647064656019211
#     y: 0.663357675075531
#   }
#   relative_keypoints {
#     x: 0.1830204725265503
#     y: 0.6804714798927307
#   }
#   relative_keypoints {
#     x: 0.1466657966375351
#     y: 0.769477903842926
#   }
#   relative_keypoints {
#     x: 0.13688918948173523
#     y: 0.8381397128105164
#   }
#   relative_keypoints {
#     x: 0.024767016991972923
#     y: 0.6716703772544861
#   }
#   relative_keypoints {
#     x: 0.20999741554260254
#     y: 0.7019577622413635
#   }
# }
#
# FPS:  275.41558867949306
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/6q/5zvzf1gs7sb7yqx2r7bg3qyw0000gn/T/ipykernel_8410/4256734727.py in <module>
#       9     while cap.isOpened():
#      10
# ---> 11         success, image = cap.read()
#      12
#      13         start = time.time()
#
# KeyboardInterrupt:
